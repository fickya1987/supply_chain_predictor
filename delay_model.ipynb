# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix
import seaborn as sns
import pickle
from imblearn.over_sampling import ADASYN
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score 
import math

# %%
df = pd.read_csv('pre_encoding_data.csv')

# %%
df = df.drop(['prod_grp','sub_class','brand', 'dosage', 'dosage_form', 'per_pack_qty','line_qty','pack_price', 'unit_price',
              'first_line','actual_del_year', 'actual_del_month', 'actual_del_day','freight','total_cost','ship_mode'], axis=1)

# %%
cat_feats = df.dtypes[df.dtypes == 'object'].index.tolist()
num_feats = df.dtypes[~df.dtypes.index.isin(cat_feats)].index.tolist()

#Convert cat_feats to categorical
for col in cat_feats:
    df[col] = df[col].astype('str')

# Removing delay from num_feats as it is the dependant variable
num_feats.remove('delay')

# %%
# Create Pipeline
numerical = Pipeline([('standard_scaler', StandardScaler())])
                            
categorical = Pipeline([('encode', OneHotEncoder()),('Dense',FunctionTransformer(csr_matrix.todense))])

preprocess = ColumnTransformer([('categorical', categorical, cat_feats),('numerical', numerical, num_feats)])

# %%
X = df.drop(columns=['delay'])
y = df['delay']

# %%
#Fit Preprocess to data
X = preprocess.fit_transform(X)

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=50)
X_train.shape
# Out:
# (7473, 367)

# %%
inputs = tf.keras.Input(shape=(X_train.shape[1],))
hide1 = tf.keras.layers.Dense(256, activation='relu')(inputs)
hide2 = tf.keras.layers.Dense(256, activation='relu')(hide1)
hide3 = tf.keras.layers.Dense(256, activation='relu')(hide2)
hide4 = tf.keras.layers.Dense(128, activation='relu')(hide3)
hide5 = tf.keras.layers.Dense(64, activation='relu')(hide4)
outputs = tf.keras.layers.Dense(1, activation='linear')(hide5)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(optimizer='adam',loss='mean_absolute_error',metrics=['mean_absolute_error'])

history = model.fit(X_train,y_train,validation_split=0.2,batch_size=32,epochs=200)
    #callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)])
# Out:
# Epoch 1/600
# 187/187 [==============================] - 1s 4ms/step - loss: 11.0310 - mean_absolute_error: 11.0310 - val_loss: 11.0724 - val_mean_absolute_error: 11.0724
# Epoch 2/600
# 187/187 [==============================] - 1s 4ms/step - loss: 10.4307 - mean_absolute_error: 10.4307 - val_loss: 10.4983 - val_mean_absolute_error: 10.4983
# Epoch 3/600
# 187/187 [==============================] - 1s 4ms/step - loss: 9.5298 - mean_absolute_error: 9.5298 - val_loss: 10.0180 - val_mean_absolute_error: 10.0180
# Epoch 4/600
# 187/187 [==============================] - 1s 4ms/step - loss: 9.2337 - mean_absolute_error: 9.2337 - val_loss: 9.9622 - val_mean_absolute_error: 9.9622
# Epoch 5/600
# 187/187 [==============================] - 1s 4ms/step - loss: 8.9920 - mean_absolute_error: 8.9920 - val_loss: 9.9178 - val_mean_absolute_error: 9.9178
# Epoch 6/600
# 187/187 [==============================] - 1s 4ms/step - loss: 8.8065 - mean_absolute_error: 8.8065 - val_loss: 9.8494 - val_mean_absolute_error: 9.8494
# Epoch 7/600
# 187/187 [==============================] - 1s 4ms/step - loss: 8.5804 - mean_absolute_error: 8.5804 - val_loss: 9.8704 - val_mean_absolute_error: 9.8704
# Epoch 8/600
# 187/187 [==============================] - 1s 4ms/step - loss: 8.4085 - mean_absolute_error: 8.4085 - val_loss: 9.7170 - val_mean_absolute_error: 9.7170
# Epoch 9/600
# 187/187 [==============================] - 1s 4ms/step - loss: 8.2525 - mean_absolute_error: 8.2525 - val_loss: 9.6467 - val_mean_absolute_error: 9.6467
# Epoch 10/600
# 187/187 [==============================] - 1s 4ms/step - loss: 8.0806 - mean_absolute_error: 8.0806 - val_loss: 9.4783 - val_mean_absolute_error: 9.4783
# Epoch 11/600
# 187/187 [==============================] - 1s 4ms/step - loss: 7.8104 - mean_absolute_error: 7.8104 - val_loss: 9.5031 - val_mean_absolute_error: 9.5031
# Epoch 12/600
# 187/187 [==============================] - 1s 4ms/step - loss: 7.7088 - mean_absolute_error: 7.7088 - val_loss: 9.2211 - val_mean_absolute_error: 9.2211
# Epoch 13/600
# 187/187 [==============================] - 1s 4ms/step - loss: 7.5521 - mean_absolute_error: 7.5521 - val_loss: 9.2617 - val_mean_absolute_error: 9.2617
# Epoch 14/600
# 187/187 [==============================] - 1s 4ms/step - loss: 7.4620 - mean_absolute_error: 7.4620 - val_loss: 9.0658 - val_mean_absolute_error: 9.0658
# Epoch 15/600
# 187/187 [==============================] - 1s 4ms/step - loss: 7.2883 - mean_absolute_error: 7.2883 - val_loss: 9.1358 - val_mean_absolute_error: 9.1358
# Epoch 16/600
# 187/187 [==============================] - 1s 4ms/step - loss: 7.1792 - mean_absolute_error: 7.1792 - val_loss: 9.5262 - val_mean_absolute_error: 9.5262
# Epoch 17/600
# 187/187 [==============================] - 1s 4ms/step - loss: 7.0216 - mean_absolute_error: 7.0216 - val_loss: 9.1628 - val_mean_absolute_error: 9.1628
# Epoch 18/600
# 187/187 [==============================] - 1s 4ms/step - loss: 7.0151 - mean_absolute_error: 7.0151 - val_loss: 9.3911 - val_mean_absolute_error: 9.3911
# Epoch 19/600
# 187/187 [==============================] - 1s 4ms/step - loss: 6.8487 - mean_absolute_error: 6.8487 - val_loss: 9.2727 - val_mean_absolute_error: 9.2727
# Epoch 20/600
# 187/187 [==============================] - 1s 4ms/step - loss: 6.7023 - mean_absolute_error: 6.7023 - val_loss: 9.3691 - val_mean_absolute_error: 9.3691
# Epoch 21/600
# 187/187 [==============================] - 1s 4ms/step - loss: 6.5497 - mean_absolute_error: 6.5497 - val_loss: 9.0995 - val_mean_absolute_error: 9.0995
# Epoch 22/600
# 187/187 [==============================] - 1s 4ms/step - loss: 6.4166 - mean_absolute_error: 6.4166 - val_loss: 8.9863 - val_mean_absolute_error: 8.9863
# Epoch 23/600
# 187/187 [==============================] - 1s 4ms/step - loss: 6.2014 - mean_absolute_error: 6.2014 - val_loss: 9.2606 - val_mean_absolute_error: 9.2606
# Epoch 24/600
# 187/187 [==============================] - 1s 4ms/step - loss: 6.1156 - mean_absolute_error: 6.1156 - val_loss: 9.0623 - val_mean_absolute_error: 9.0623
# Epoch 25/600
# 187/187 [==============================] - 1s 4ms/step - loss: 6.0854 - mean_absolute_error: 6.0854 - val_loss: 9.4562 - val_mean_absolute_error: 9.4562
# Epoch 26/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.9378 - mean_absolute_error: 5.9378 - val_loss: 9.1621 - val_mean_absolute_error: 9.1621
# Epoch 27/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.8184 - mean_absolute_error: 5.8184 - val_loss: 9.0484 - val_mean_absolute_error: 9.0484
# Epoch 28/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.8056 - mean_absolute_error: 5.8056 - val_loss: 9.0714 - val_mean_absolute_error: 9.0714
# Epoch 29/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.7411 - mean_absolute_error: 5.7411 - val_loss: 9.1312 - val_mean_absolute_error: 9.1312
# Epoch 30/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.5559 - mean_absolute_error: 5.5559 - val_loss: 8.9080 - val_mean_absolute_error: 8.9080
# Epoch 31/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.5122 - mean_absolute_error: 5.5122 - val_loss: 8.9842 - val_mean_absolute_error: 8.9842
# Epoch 32/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.4128 - mean_absolute_error: 5.4128 - val_loss: 9.3919 - val_mean_absolute_error: 9.3919
# Epoch 33/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.3794 - mean_absolute_error: 5.3794 - val_loss: 8.8155 - val_mean_absolute_error: 8.8155
# Epoch 34/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.2781 - mean_absolute_error: 5.2781 - val_loss: 9.0618 - val_mean_absolute_error: 9.0618
# Epoch 35/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.2445 - mean_absolute_error: 5.2445 - val_loss: 8.8410 - val_mean_absolute_error: 8.8410
# Epoch 36/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.1589 - mean_absolute_error: 5.1589 - val_loss: 8.7919 - val_mean_absolute_error: 8.7919
# Epoch 37/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.0968 - mean_absolute_error: 5.0968 - val_loss: 8.7976 - val_mean_absolute_error: 8.7976
# Epoch 38/600
# 187/187 [==============================] - 1s 4ms/step - loss: 5.0302 - mean_absolute_error: 5.0302 - val_loss: 8.8960 - val_mean_absolute_error: 8.8960
# Epoch 39/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.9533 - mean_absolute_error: 4.9533 - val_loss: 8.9943 - val_mean_absolute_error: 8.9943
# Epoch 40/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.9167 - mean_absolute_error: 4.9167 - val_loss: 8.7332 - val_mean_absolute_error: 8.7332
# Epoch 41/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.7991 - mean_absolute_error: 4.7991 - val_loss: 9.0230 - val_mean_absolute_error: 9.0230
# Epoch 42/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.7825 - mean_absolute_error: 4.7825 - val_loss: 8.8229 - val_mean_absolute_error: 8.8229
# Epoch 43/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.6861 - mean_absolute_error: 4.6861 - val_loss: 8.7292 - val_mean_absolute_error: 8.7292
# Epoch 44/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.6579 - mean_absolute_error: 4.6579 - val_loss: 8.9497 - val_mean_absolute_error: 8.9497
# Epoch 45/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.5835 - mean_absolute_error: 4.5835 - val_loss: 8.8784 - val_mean_absolute_error: 8.8784
# Epoch 46/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.5809 - mean_absolute_error: 4.5809 - val_loss: 8.7072 - val_mean_absolute_error: 8.7072
# Epoch 47/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.5289 - mean_absolute_error: 4.5289 - val_loss: 8.8795 - val_mean_absolute_error: 8.8795
# Epoch 48/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.5552 - mean_absolute_error: 4.5552 - val_loss: 8.5895 - val_mean_absolute_error: 8.5895
# Epoch 49/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.3939 - mean_absolute_error: 4.3939 - val_loss: 8.6023 - val_mean_absolute_error: 8.6023
# Epoch 50/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.3862 - mean_absolute_error: 4.3862 - val_loss: 8.4439 - val_mean_absolute_error: 8.4439
# Epoch 51/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.3452 - mean_absolute_error: 4.3452 - val_loss: 8.6460 - val_mean_absolute_error: 8.6460
# Epoch 52/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.3390 - mean_absolute_error: 4.3390 - val_loss: 8.6047 - val_mean_absolute_error: 8.6047
# Epoch 53/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.2805 - mean_absolute_error: 4.2805 - val_loss: 8.3282 - val_mean_absolute_error: 8.3282
# Epoch 54/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.1650 - mean_absolute_error: 4.1650 - val_loss: 8.4313 - val_mean_absolute_error: 8.4313
# Epoch 55/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.2070 - mean_absolute_error: 4.2070 - val_loss: 8.5849 - val_mean_absolute_error: 8.5849
# Epoch 56/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.1079 - mean_absolute_error: 4.1079 - val_loss: 8.6123 - val_mean_absolute_error: 8.6123
# Epoch 57/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.1137 - mean_absolute_error: 4.1137 - val_loss: 8.6468 - val_mean_absolute_error: 8.6468
# Epoch 58/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.1601 - mean_absolute_error: 4.1601 - val_loss: 8.5811 - val_mean_absolute_error: 8.5811
# Epoch 59/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.0846 - mean_absolute_error: 4.0846 - val_loss: 8.7483 - val_mean_absolute_error: 8.7483
# Epoch 60/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.0441 - mean_absolute_error: 4.0441 - val_loss: 8.7473 - val_mean_absolute_error: 8.7473
# Epoch 61/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.0043 - mean_absolute_error: 4.0043 - val_loss: 8.8858 - val_mean_absolute_error: 8.8858
# Epoch 62/600
# 187/187 [==============================] - 1s 4ms/step - loss: 4.0639 - mean_absolute_error: 4.0639 - val_loss: 8.3013 - val_mean_absolute_error: 8.3013
# Epoch 63/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.9580 - mean_absolute_error: 3.9580 - val_loss: 8.4434 - val_mean_absolute_error: 8.4434
# Epoch 64/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.9016 - mean_absolute_error: 3.9016 - val_loss: 8.4255 - val_mean_absolute_error: 8.4255
# Epoch 65/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.9075 - mean_absolute_error: 3.9075 - val_loss: 8.7367 - val_mean_absolute_error: 8.7367
# Epoch 66/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.8846 - mean_absolute_error: 3.8846 - val_loss: 8.5308 - val_mean_absolute_error: 8.5308
# Epoch 67/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.8414 - mean_absolute_error: 3.8414 - val_loss: 8.6581 - val_mean_absolute_error: 8.6581
# Epoch 68/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.8559 - mean_absolute_error: 3.8559 - val_loss: 8.5144 - val_mean_absolute_error: 8.5144
# Epoch 69/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.7941 - mean_absolute_error: 3.7941 - val_loss: 8.3374 - val_mean_absolute_error: 8.3374
# Epoch 70/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.7507 - mean_absolute_error: 3.7507 - val_loss: 8.3494 - val_mean_absolute_error: 8.3494
# Epoch 71/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.7597 - mean_absolute_error: 3.7597 - val_loss: 8.4712 - val_mean_absolute_error: 8.4712
# Epoch 72/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.7094 - mean_absolute_error: 3.7094 - val_loss: 8.4570 - val_mean_absolute_error: 8.4570
# Epoch 73/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.7047 - mean_absolute_error: 3.7047 - val_loss: 8.6450 - val_mean_absolute_error: 8.6450
# Epoch 74/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.7133 - mean_absolute_error: 3.7133 - val_loss: 8.4528 - val_mean_absolute_error: 8.4528
# Epoch 75/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.6070 - mean_absolute_error: 3.6070 - val_loss: 8.4201 - val_mean_absolute_error: 8.4201
# Epoch 76/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.6063 - mean_absolute_error: 3.6063 - val_loss: 8.4673 - val_mean_absolute_error: 8.4673
# Epoch 77/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.6185 - mean_absolute_error: 3.6185 - val_loss: 8.4506 - val_mean_absolute_error: 8.4506
# Epoch 78/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.6455 - mean_absolute_error: 3.6455 - val_loss: 8.3607 - val_mean_absolute_error: 8.3607
# Epoch 79/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.5699 - mean_absolute_error: 3.5699 - val_loss: 8.6376 - val_mean_absolute_error: 8.6376
# Epoch 80/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.5349 - mean_absolute_error: 3.5349 - val_loss: 8.5448 - val_mean_absolute_error: 8.5448
# Epoch 81/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.5333 - mean_absolute_error: 3.5333 - val_loss: 8.5555 - val_mean_absolute_error: 8.5555
# Epoch 82/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.4897 - mean_absolute_error: 3.4897 - val_loss: 8.5513 - val_mean_absolute_error: 8.5513
# Epoch 83/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.4989 - mean_absolute_error: 3.4989 - val_loss: 8.4145 - val_mean_absolute_error: 8.4145
# Epoch 84/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.4369 - mean_absolute_error: 3.4369 - val_loss: 8.5712 - val_mean_absolute_error: 8.5712
# Epoch 85/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.5009 - mean_absolute_error: 3.5009 - val_loss: 8.6586 - val_mean_absolute_error: 8.6586
# Epoch 86/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.4815 - mean_absolute_error: 3.4815 - val_loss: 8.2685 - val_mean_absolute_error: 8.2685
# Epoch 87/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.3366 - mean_absolute_error: 3.3366 - val_loss: 8.5083 - val_mean_absolute_error: 8.5083
# Epoch 88/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.3791 - mean_absolute_error: 3.3791 - val_loss: 8.8017 - val_mean_absolute_error: 8.8017
# Epoch 89/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.3865 - mean_absolute_error: 3.3865 - val_loss: 8.2714 - val_mean_absolute_error: 8.2714
# Epoch 90/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.4284 - mean_absolute_error: 3.4284 - val_loss: 8.4397 - val_mean_absolute_error: 8.4397
# Epoch 91/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.4343 - mean_absolute_error: 3.4343 - val_loss: 8.4851 - val_mean_absolute_error: 8.4851
# Epoch 92/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.3114 - mean_absolute_error: 3.3114 - val_loss: 8.4179 - val_mean_absolute_error: 8.4179
# Epoch 93/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.2644 - mean_absolute_error: 3.2644 - val_loss: 8.3867 - val_mean_absolute_error: 8.3867
# Epoch 94/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.3287 - mean_absolute_error: 3.3287 - val_loss: 8.2915 - val_mean_absolute_error: 8.2915
# Epoch 95/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.2940 - mean_absolute_error: 3.2940 - val_loss: 8.5403 - val_mean_absolute_error: 8.5403
# Epoch 96/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.2322 - mean_absolute_error: 3.2322 - val_loss: 8.3311 - val_mean_absolute_error: 8.3311
# Epoch 97/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.2119 - mean_absolute_error: 3.2119 - val_loss: 8.4856 - val_mean_absolute_error: 8.4856
# Epoch 98/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.1942 - mean_absolute_error: 3.1942 - val_loss: 8.5854 - val_mean_absolute_error: 8.5854
# Epoch 99/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.2320 - mean_absolute_error: 3.2320 - val_loss: 8.3301 - val_mean_absolute_error: 8.3301
# Epoch 100/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.2038 - mean_absolute_error: 3.2038 - val_loss: 8.3693 - val_mean_absolute_error: 8.3693
# Epoch 101/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.1992 - mean_absolute_error: 3.1992 - val_loss: 8.4108 - val_mean_absolute_error: 8.4108
# Epoch 102/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.1895 - mean_absolute_error: 3.1895 - val_loss: 8.4560 - val_mean_absolute_error: 8.4560
# Epoch 103/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.2059 - mean_absolute_error: 3.2059 - val_loss: 8.3934 - val_mean_absolute_error: 8.3934
# Epoch 104/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.1078 - mean_absolute_error: 3.1078 - val_loss: 8.2385 - val_mean_absolute_error: 8.2385
# Epoch 105/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.0933 - mean_absolute_error: 3.0933 - val_loss: 8.2551 - val_mean_absolute_error: 8.2551
# Epoch 106/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.0844 - mean_absolute_error: 3.0844 - val_loss: 8.4293 - val_mean_absolute_error: 8.4293
# Epoch 107/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.0917 - mean_absolute_error: 3.0917 - val_loss: 8.2632 - val_mean_absolute_error: 8.2632
# Epoch 108/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.1095 - mean_absolute_error: 3.1095 - val_loss: 8.5260 - val_mean_absolute_error: 8.5260
# Epoch 109/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.0689 - mean_absolute_error: 3.0689 - val_loss: 8.2496 - val_mean_absolute_error: 8.2496
# Epoch 110/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.0981 - mean_absolute_error: 3.0981 - val_loss: 8.5339 - val_mean_absolute_error: 8.5339
# Epoch 111/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.0148 - mean_absolute_error: 3.0148 - val_loss: 8.4043 - val_mean_absolute_error: 8.4043
# Epoch 112/600
# 187/187 [==============================] - 1s 4ms/step - loss: 3.1317 - mean_absolute_error: 3.1317 - val_loss: 8.3947 - val_mean_absolute_error: 8.3947
# Epoch 113/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.9874 - mean_absolute_error: 2.9874 - val_loss: 8.5124 - val_mean_absolute_error: 8.5124
# Epoch 114/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.9604 - mean_absolute_error: 2.9604 - val_loss: 8.4945 - val_mean_absolute_error: 8.4945
# Epoch 115/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.9290 - mean_absolute_error: 2.9290 - val_loss: 8.2189 - val_mean_absolute_error: 8.2189
# Epoch 116/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.9474 - mean_absolute_error: 2.9474 - val_loss: 8.2952 - val_mean_absolute_error: 8.2952
# Epoch 117/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.9588 - mean_absolute_error: 2.9588 - val_loss: 8.3184 - val_mean_absolute_error: 8.3184
# Epoch 118/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.9439 - mean_absolute_error: 2.9439 - val_loss: 8.4528 - val_mean_absolute_error: 8.4528
# Epoch 119/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.9544 - mean_absolute_error: 2.9544 - val_loss: 8.2936 - val_mean_absolute_error: 8.2936
# Epoch 120/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.9112 - mean_absolute_error: 2.9112 - val_loss: 8.3434 - val_mean_absolute_error: 8.3434
# Epoch 121/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.9120 - mean_absolute_error: 2.9120 - val_loss: 8.0797 - val_mean_absolute_error: 8.0797
# Epoch 122/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.9166 - mean_absolute_error: 2.9166 - val_loss: 8.2527 - val_mean_absolute_error: 8.2527
# Epoch 123/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.8999 - mean_absolute_error: 2.8999 - val_loss: 8.2998 - val_mean_absolute_error: 8.2998
# Epoch 124/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.8185 - mean_absolute_error: 2.8185 - val_loss: 8.2987 - val_mean_absolute_error: 8.2987
# Epoch 125/600
# 187/187 [==============================] - 1s 7ms/step - loss: 2.8267 - mean_absolute_error: 2.8267 - val_loss: 8.4868 - val_mean_absolute_error: 8.4868
# Epoch 126/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.8503 - mean_absolute_error: 2.8503 - val_loss: 8.1637 - val_mean_absolute_error: 8.1637
# Epoch 127/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.8113 - mean_absolute_error: 2.8113 - val_loss: 8.1682 - val_mean_absolute_error: 8.1682
# Epoch 128/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.8316 - mean_absolute_error: 2.8316 - val_loss: 8.3609 - val_mean_absolute_error: 8.3609
# Epoch 129/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7767 - mean_absolute_error: 2.7767 - val_loss: 8.4502 - val_mean_absolute_error: 8.4502
# Epoch 130/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7884 - mean_absolute_error: 2.7884 - val_loss: 8.3926 - val_mean_absolute_error: 8.3926
# Epoch 131/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7629 - mean_absolute_error: 2.7629 - val_loss: 8.2721 - val_mean_absolute_error: 8.2721
# Epoch 132/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7401 - mean_absolute_error: 2.7401 - val_loss: 8.1718 - val_mean_absolute_error: 8.1718
# Epoch 133/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7779 - mean_absolute_error: 2.7779 - val_loss: 8.2441 - val_mean_absolute_error: 8.2441
# Epoch 134/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7221 - mean_absolute_error: 2.7221 - val_loss: 8.0232 - val_mean_absolute_error: 8.0232
# Epoch 135/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7000 - mean_absolute_error: 2.7000 - val_loss: 8.3892 - val_mean_absolute_error: 8.3892
# Epoch 136/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7322 - mean_absolute_error: 2.7322 - val_loss: 8.2076 - val_mean_absolute_error: 8.2076
# Epoch 137/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7420 - mean_absolute_error: 2.7420 - val_loss: 8.2952 - val_mean_absolute_error: 8.2952
# Epoch 138/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7253 - mean_absolute_error: 2.7253 - val_loss: 8.3105 - val_mean_absolute_error: 8.3105
# Epoch 139/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.7127 - mean_absolute_error: 2.7127 - val_loss: 8.3090 - val_mean_absolute_error: 8.3090
# Epoch 140/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7071 - mean_absolute_error: 2.7071 - val_loss: 8.2900 - val_mean_absolute_error: 8.2900
# Epoch 141/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7476 - mean_absolute_error: 2.7476 - val_loss: 8.2619 - val_mean_absolute_error: 8.2619
# Epoch 142/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7029 - mean_absolute_error: 2.7029 - val_loss: 8.4205 - val_mean_absolute_error: 8.4205
# Epoch 143/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.7173 - mean_absolute_error: 2.7173 - val_loss: 8.1124 - val_mean_absolute_error: 8.1124
# Epoch 144/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.6904 - mean_absolute_error: 2.6904 - val_loss: 8.3153 - val_mean_absolute_error: 8.3153
# Epoch 145/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.6065 - mean_absolute_error: 2.6065 - val_loss: 8.1579 - val_mean_absolute_error: 8.1579
# Epoch 146/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.6669 - mean_absolute_error: 2.6669 - val_loss: 8.2345 - val_mean_absolute_error: 8.2345
# Epoch 147/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.6250 - mean_absolute_error: 2.6250 - val_loss: 8.3733 - val_mean_absolute_error: 8.3733
# Epoch 148/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.6216 - mean_absolute_error: 2.6216 - val_loss: 8.2035 - val_mean_absolute_error: 8.2035
# Epoch 149/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.5932 - mean_absolute_error: 2.5932 - val_loss: 8.4031 - val_mean_absolute_error: 8.4031
# Epoch 150/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.5825 - mean_absolute_error: 2.5825 - val_loss: 8.2275 - val_mean_absolute_error: 8.2275
# Epoch 151/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.5637 - mean_absolute_error: 2.5637 - val_loss: 8.0954 - val_mean_absolute_error: 8.0954
# Epoch 152/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.6128 - mean_absolute_error: 2.6128 - val_loss: 8.2683 - val_mean_absolute_error: 8.2683
# Epoch 153/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.6241 - mean_absolute_error: 2.6241 - val_loss: 8.3499 - val_mean_absolute_error: 8.3499
# Epoch 154/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.5703 - mean_absolute_error: 2.5703 - val_loss: 8.4302 - val_mean_absolute_error: 8.4302
# Epoch 155/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.6104 - mean_absolute_error: 2.6104 - val_loss: 8.3189 - val_mean_absolute_error: 8.3189
# Epoch 156/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.5882 - mean_absolute_error: 2.5882 - val_loss: 8.2417 - val_mean_absolute_error: 8.2417
# Epoch 157/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.5765 - mean_absolute_error: 2.5765 - val_loss: 7.9378 - val_mean_absolute_error: 7.9378
# Epoch 158/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.5775 - mean_absolute_error: 2.5775 - val_loss: 8.2067 - val_mean_absolute_error: 8.2067
# Epoch 159/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.5438 - mean_absolute_error: 2.5438 - val_loss: 8.1730 - val_mean_absolute_error: 8.1730
# Epoch 160/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4921 - mean_absolute_error: 2.4921 - val_loss: 8.4024 - val_mean_absolute_error: 8.4024
# Epoch 161/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.5248 - mean_absolute_error: 2.5248 - val_loss: 8.2514 - val_mean_absolute_error: 8.2514
# Epoch 162/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4796 - mean_absolute_error: 2.4796 - val_loss: 8.2489 - val_mean_absolute_error: 8.2489
# Epoch 163/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4910 - mean_absolute_error: 2.4910 - val_loss: 8.2208 - val_mean_absolute_error: 8.2208
# Epoch 164/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.5040 - mean_absolute_error: 2.5040 - val_loss: 8.3392 - val_mean_absolute_error: 8.3392
# Epoch 165/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4991 - mean_absolute_error: 2.4991 - val_loss: 8.2436 - val_mean_absolute_error: 8.2436
# Epoch 166/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4612 - mean_absolute_error: 2.4612 - val_loss: 8.3233 - val_mean_absolute_error: 8.3233
# Epoch 167/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4979 - mean_absolute_error: 2.4979 - val_loss: 8.3233 - val_mean_absolute_error: 8.3233
# Epoch 168/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.5278 - mean_absolute_error: 2.5278 - val_loss: 8.2038 - val_mean_absolute_error: 8.2038
# Epoch 169/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4894 - mean_absolute_error: 2.4894 - val_loss: 8.0769 - val_mean_absolute_error: 8.0769
# Epoch 170/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4988 - mean_absolute_error: 2.4988 - val_loss: 8.1362 - val_mean_absolute_error: 8.1362
# Epoch 171/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4797 - mean_absolute_error: 2.4797 - val_loss: 8.3171 - val_mean_absolute_error: 8.3171
# Epoch 172/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4883 - mean_absolute_error: 2.4883 - val_loss: 8.0767 - val_mean_absolute_error: 8.0767
# Epoch 173/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4761 - mean_absolute_error: 2.4761 - val_loss: 8.3144 - val_mean_absolute_error: 8.3144
# Epoch 174/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4386 - mean_absolute_error: 2.4386 - val_loss: 8.4677 - val_mean_absolute_error: 8.4677
# Epoch 175/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4616 - mean_absolute_error: 2.4616 - val_loss: 8.2932 - val_mean_absolute_error: 8.2932
# Epoch 176/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4408 - mean_absolute_error: 2.4408 - val_loss: 8.1472 - val_mean_absolute_error: 8.1472
# Epoch 177/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4245 - mean_absolute_error: 2.4245 - val_loss: 8.2170 - val_mean_absolute_error: 8.2170
# Epoch 178/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3884 - mean_absolute_error: 2.3884 - val_loss: 8.2918 - val_mean_absolute_error: 8.2918
# Epoch 179/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.4314 - mean_absolute_error: 2.4314 - val_loss: 8.2184 - val_mean_absolute_error: 8.2184
# Epoch 180/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3695 - mean_absolute_error: 2.3695 - val_loss: 8.1168 - val_mean_absolute_error: 8.1168
# Epoch 181/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3981 - mean_absolute_error: 2.3981 - val_loss: 8.2755 - val_mean_absolute_error: 8.2755
# Epoch 182/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4579 - mean_absolute_error: 2.4579 - val_loss: 8.0904 - val_mean_absolute_error: 8.0904
# Epoch 183/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3696 - mean_absolute_error: 2.3696 - val_loss: 8.2638 - val_mean_absolute_error: 8.2638
# Epoch 184/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3852 - mean_absolute_error: 2.3852 - val_loss: 8.1457 - val_mean_absolute_error: 8.1457
# Epoch 185/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3783 - mean_absolute_error: 2.3783 - val_loss: 8.1128 - val_mean_absolute_error: 8.1128
# Epoch 186/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3951 - mean_absolute_error: 2.3951 - val_loss: 8.2445 - val_mean_absolute_error: 8.2445
# Epoch 187/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3336 - mean_absolute_error: 2.3336 - val_loss: 8.3840 - val_mean_absolute_error: 8.3840
# Epoch 188/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4074 - mean_absolute_error: 2.4074 - val_loss: 8.2851 - val_mean_absolute_error: 8.2851
# Epoch 189/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3883 - mean_absolute_error: 2.3883 - val_loss: 8.3534 - val_mean_absolute_error: 8.3534
# Epoch 190/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3479 - mean_absolute_error: 2.3479 - val_loss: 8.1729 - val_mean_absolute_error: 8.1729
# Epoch 191/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3221 - mean_absolute_error: 2.3221 - val_loss: 8.1266 - val_mean_absolute_error: 8.1266
# Epoch 192/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3665 - mean_absolute_error: 2.3665 - val_loss: 8.4133 - val_mean_absolute_error: 8.4133
# Epoch 193/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3399 - mean_absolute_error: 2.3399 - val_loss: 8.1750 - val_mean_absolute_error: 8.1750
# Epoch 194/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3164 - mean_absolute_error: 2.3164 - val_loss: 8.2226 - val_mean_absolute_error: 8.2226
# Epoch 195/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3316 - mean_absolute_error: 2.3316 - val_loss: 8.2098 - val_mean_absolute_error: 8.2098
# Epoch 196/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2967 - mean_absolute_error: 2.2967 - val_loss: 8.2794 - val_mean_absolute_error: 8.2794
# Epoch 197/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3198 - mean_absolute_error: 2.3198 - val_loss: 8.2145 - val_mean_absolute_error: 8.2145
# Epoch 198/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3603 - mean_absolute_error: 2.3603 - val_loss: 8.2636 - val_mean_absolute_error: 8.2636
# Epoch 199/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3062 - mean_absolute_error: 2.3062 - val_loss: 8.3880 - val_mean_absolute_error: 8.3880
# Epoch 200/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4026 - mean_absolute_error: 2.4026 - val_loss: 8.2343 - val_mean_absolute_error: 8.2343
# Epoch 201/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2939 - mean_absolute_error: 2.2939 - val_loss: 8.1318 - val_mean_absolute_error: 8.1318
# Epoch 202/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3132 - mean_absolute_error: 2.3132 - val_loss: 8.2996 - val_mean_absolute_error: 8.2996
# Epoch 203/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2715 - mean_absolute_error: 2.2715 - val_loss: 8.0987 - val_mean_absolute_error: 8.0987
# Epoch 204/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3129 - mean_absolute_error: 2.3129 - val_loss: 8.4343 - val_mean_absolute_error: 8.4343
# Epoch 205/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2418 - mean_absolute_error: 2.2418 - val_loss: 8.3206 - val_mean_absolute_error: 8.3206
# Epoch 206/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2983 - mean_absolute_error: 2.2983 - val_loss: 8.2642 - val_mean_absolute_error: 8.2642
# Epoch 207/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2687 - mean_absolute_error: 2.2687 - val_loss: 8.1250 - val_mean_absolute_error: 8.1250
# Epoch 208/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2334 - mean_absolute_error: 2.2334 - val_loss: 8.2150 - val_mean_absolute_error: 8.2150
# Epoch 209/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2601 - mean_absolute_error: 2.2601 - val_loss: 8.0267 - val_mean_absolute_error: 8.0267
# Epoch 210/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2454 - mean_absolute_error: 2.2454 - val_loss: 8.1877 - val_mean_absolute_error: 8.1877
# Epoch 211/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2759 - mean_absolute_error: 2.2759 - val_loss: 8.2887 - val_mean_absolute_error: 8.2887
# Epoch 212/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2334 - mean_absolute_error: 2.2334 - val_loss: 8.2886 - val_mean_absolute_error: 8.2886
# Epoch 213/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2583 - mean_absolute_error: 2.2583 - val_loss: 8.2174 - val_mean_absolute_error: 8.2174
# Epoch 214/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2208 - mean_absolute_error: 2.2208 - val_loss: 8.0740 - val_mean_absolute_error: 8.0740
# Epoch 215/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1879 - mean_absolute_error: 2.1879 - val_loss: 8.4156 - val_mean_absolute_error: 8.4156
# Epoch 216/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2704 - mean_absolute_error: 2.2704 - val_loss: 7.9631 - val_mean_absolute_error: 7.9631
# Epoch 217/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2127 - mean_absolute_error: 2.2127 - val_loss: 8.2458 - val_mean_absolute_error: 8.2458
# Epoch 218/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1827 - mean_absolute_error: 2.1827 - val_loss: 8.2070 - val_mean_absolute_error: 8.2070
# Epoch 219/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2087 - mean_absolute_error: 2.2087 - val_loss: 8.0674 - val_mean_absolute_error: 8.0674
# Epoch 220/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1966 - mean_absolute_error: 2.1966 - val_loss: 8.2332 - val_mean_absolute_error: 8.2332
# Epoch 221/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2139 - mean_absolute_error: 2.2139 - val_loss: 8.0640 - val_mean_absolute_error: 8.0640
# Epoch 222/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2236 - mean_absolute_error: 2.2236 - val_loss: 8.2902 - val_mean_absolute_error: 8.2902
# Epoch 223/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1901 - mean_absolute_error: 2.1901 - val_loss: 8.0483 - val_mean_absolute_error: 8.0483
# Epoch 224/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1695 - mean_absolute_error: 2.1695 - val_loss: 8.1972 - val_mean_absolute_error: 8.1972
# Epoch 225/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2080 - mean_absolute_error: 2.2080 - val_loss: 8.1721 - val_mean_absolute_error: 8.1721
# Epoch 226/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1673 - mean_absolute_error: 2.1673 - val_loss: 8.1508 - val_mean_absolute_error: 8.1508
# Epoch 227/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1566 - mean_absolute_error: 2.1566 - val_loss: 8.2329 - val_mean_absolute_error: 8.2329
# Epoch 228/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1499 - mean_absolute_error: 2.1499 - val_loss: 8.2545 - val_mean_absolute_error: 8.2545
# Epoch 229/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.1466 - mean_absolute_error: 2.1466 - val_loss: 8.2216 - val_mean_absolute_error: 8.2216
# Epoch 230/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1858 - mean_absolute_error: 2.1858 - val_loss: 8.3988 - val_mean_absolute_error: 8.3988
# Epoch 231/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1288 - mean_absolute_error: 2.1288 - val_loss: 8.2854 - val_mean_absolute_error: 8.2854
# Epoch 232/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1671 - mean_absolute_error: 2.1671 - val_loss: 8.3591 - val_mean_absolute_error: 8.3591
# Epoch 233/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1724 - mean_absolute_error: 2.1724 - val_loss: 8.1777 - val_mean_absolute_error: 8.1777
# Epoch 234/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1717 - mean_absolute_error: 2.1717 - val_loss: 8.3886 - val_mean_absolute_error: 8.3886
# Epoch 235/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1656 - mean_absolute_error: 2.1656 - val_loss: 8.1743 - val_mean_absolute_error: 8.1743
# Epoch 236/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1129 - mean_absolute_error: 2.1129 - val_loss: 8.3126 - val_mean_absolute_error: 8.3126
# Epoch 237/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0666 - mean_absolute_error: 2.0666 - val_loss: 8.1804 - val_mean_absolute_error: 8.1804
# Epoch 238/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1095 - mean_absolute_error: 2.1095 - val_loss: 8.1791 - val_mean_absolute_error: 8.1791
# Epoch 239/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1125 - mean_absolute_error: 2.1125 - val_loss: 8.3106 - val_mean_absolute_error: 8.3106
# Epoch 240/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.0965 - mean_absolute_error: 2.0965 - val_loss: 8.4040 - val_mean_absolute_error: 8.4040
# Epoch 241/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1262 - mean_absolute_error: 2.1262 - val_loss: 8.4701 - val_mean_absolute_error: 8.4701
# Epoch 242/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1415 - mean_absolute_error: 2.1415 - val_loss: 8.2179 - val_mean_absolute_error: 8.2179
# Epoch 243/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1063 - mean_absolute_error: 2.1063 - val_loss: 8.1983 - val_mean_absolute_error: 8.1983
# Epoch 244/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1245 - mean_absolute_error: 2.1245 - val_loss: 8.1234 - val_mean_absolute_error: 8.1234
# Epoch 245/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0781 - mean_absolute_error: 2.0781 - val_loss: 8.3239 - val_mean_absolute_error: 8.3239
# Epoch 246/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0584 - mean_absolute_error: 2.0584 - val_loss: 8.4899 - val_mean_absolute_error: 8.4899
# Epoch 247/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0706 - mean_absolute_error: 2.0706 - val_loss: 8.5043 - val_mean_absolute_error: 8.5043
# Epoch 248/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1342 - mean_absolute_error: 2.1342 - val_loss: 8.2648 - val_mean_absolute_error: 8.2648
# Epoch 249/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1126 - mean_absolute_error: 2.1126 - val_loss: 8.1981 - val_mean_absolute_error: 8.1981
# Epoch 250/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.0635 - mean_absolute_error: 2.0635 - val_loss: 8.3672 - val_mean_absolute_error: 8.3672
# Epoch 251/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0869 - mean_absolute_error: 2.0869 - val_loss: 8.2642 - val_mean_absolute_error: 8.2642
# Epoch 252/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0465 - mean_absolute_error: 2.0465 - val_loss: 8.4664 - val_mean_absolute_error: 8.4664
# Epoch 253/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.1201 - mean_absolute_error: 2.1201 - val_loss: 8.4643 - val_mean_absolute_error: 8.4643
# Epoch 254/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0912 - mean_absolute_error: 2.0912 - val_loss: 8.3793 - val_mean_absolute_error: 8.3793
# Epoch 255/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0494 - mean_absolute_error: 2.0494 - val_loss: 8.2831 - val_mean_absolute_error: 8.2831
# Epoch 256/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0254 - mean_absolute_error: 2.0254 - val_loss: 8.5196 - val_mean_absolute_error: 8.5196
# Epoch 257/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0862 - mean_absolute_error: 2.0862 - val_loss: 8.4661 - val_mean_absolute_error: 8.4661
# Epoch 258/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0168 - mean_absolute_error: 2.0168 - val_loss: 8.3018 - val_mean_absolute_error: 8.3018
# Epoch 259/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0901 - mean_absolute_error: 2.0901 - val_loss: 8.2350 - val_mean_absolute_error: 8.2350
# Epoch 260/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.0399 - mean_absolute_error: 2.0399 - val_loss: 8.3455 - val_mean_absolute_error: 8.3455
# Epoch 261/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0795 - mean_absolute_error: 2.0795 - val_loss: 8.3209 - val_mean_absolute_error: 8.3209
# Epoch 262/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0442 - mean_absolute_error: 2.0442 - val_loss: 8.2013 - val_mean_absolute_error: 8.2013
# Epoch 263/600
# 187/187 [==============================] - 1s 5ms/step - loss: 1.9879 - mean_absolute_error: 1.9879 - val_loss: 8.2332 - val_mean_absolute_error: 8.2332
# Epoch 264/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0132 - mean_absolute_error: 2.0132 - val_loss: 8.4194 - val_mean_absolute_error: 8.4194
# Epoch 265/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0292 - mean_absolute_error: 2.0292 - val_loss: 8.2524 - val_mean_absolute_error: 8.2524
# Epoch 266/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9836 - mean_absolute_error: 1.9836 - val_loss: 8.3675 - val_mean_absolute_error: 8.3675
# Epoch 267/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0230 - mean_absolute_error: 2.0230 - val_loss: 8.3039 - val_mean_absolute_error: 8.3039
# Epoch 268/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0307 - mean_absolute_error: 2.0307 - val_loss: 8.4096 - val_mean_absolute_error: 8.4096
# Epoch 269/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0430 - mean_absolute_error: 2.0430 - val_loss: 8.3924 - val_mean_absolute_error: 8.3924
# Epoch 270/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.0385 - mean_absolute_error: 2.0385 - val_loss: 8.2480 - val_mean_absolute_error: 8.2480
# Epoch 271/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9963 - mean_absolute_error: 1.9963 - val_loss: 8.2084 - val_mean_absolute_error: 8.2084
# Epoch 272/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0304 - mean_absolute_error: 2.0304 - val_loss: 8.2141 - val_mean_absolute_error: 8.2141
# Epoch 273/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0077 - mean_absolute_error: 2.0077 - val_loss: 8.4077 - val_mean_absolute_error: 8.4077
# Epoch 274/600
# 187/187 [==============================] - 1s 5ms/step - loss: 2.0040 - mean_absolute_error: 2.0040 - val_loss: 8.4238 - val_mean_absolute_error: 8.4238
# Epoch 275/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0079 - mean_absolute_error: 2.0079 - val_loss: 8.5473 - val_mean_absolute_error: 8.5473
# Epoch 276/600
# 187/187 [==============================] - 1s 4ms/step - loss: 2.0485 - mean_absolute_error: 2.0485 - val_loss: 8.3902 - val_mean_absolute_error: 8.3902
# Epoch 277/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9887 - mean_absolute_error: 1.9887 - val_loss: 8.4334 - val_mean_absolute_error: 8.4334
# Epoch 278/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9483 - mean_absolute_error: 1.9483 - val_loss: 8.2874 - val_mean_absolute_error: 8.2874
# Epoch 279/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9537 - mean_absolute_error: 1.9537 - val_loss: 8.3596 - val_mean_absolute_error: 8.3596
# Epoch 280/600
# 187/187 [==============================] - 1s 5ms/step - loss: 1.9529 - mean_absolute_error: 1.9529 - val_loss: 8.3824 - val_mean_absolute_error: 8.3824
# Epoch 281/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9560 - mean_absolute_error: 1.9560 - val_loss: 8.4296 - val_mean_absolute_error: 8.4296
# Epoch 282/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9633 - mean_absolute_error: 1.9633 - val_loss: 8.3256 - val_mean_absolute_error: 8.3256
# Epoch 283/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9780 - mean_absolute_error: 1.9780 - val_loss: 8.3607 - val_mean_absolute_error: 8.3607
# Epoch 284/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9401 - mean_absolute_error: 1.9401 - val_loss: 8.3502 - val_mean_absolute_error: 8.3502
# Epoch 285/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9635 - mean_absolute_error: 1.9635 - val_loss: 8.1998 - val_mean_absolute_error: 8.1998
# Epoch 286/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9617 - mean_absolute_error: 1.9617 - val_loss: 8.3603 - val_mean_absolute_error: 8.3603
# Epoch 287/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9350 - mean_absolute_error: 1.9350 - val_loss: 8.2266 - val_mean_absolute_error: 8.2266
# Epoch 288/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.9361 - mean_absolute_error: 1.9361 - val_loss: 8.2811 - val_mean_absolute_error: 8.2811
# ...
# Epoch 445/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.6124 - mean_absolute_error: 1.6124 - val_loss: 8.3505 - val_mean_absolute_error: 8.3505
# Epoch 446/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5977 - mean_absolute_error: 1.5977 - val_loss: 8.2240 - val_mean_absolute_error: 8.2240
# Epoch 447/600
# 187/187 [==============================] - 1s 3ms/step - loss: 1.5856 - mean_absolute_error: 1.5856 - val_loss: 8.2142 - val_mean_absolute_error: 8.2142
# Epoch 448/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.6034 - mean_absolute_error: 1.6034 - val_loss: 8.4519 - val_mean_absolute_error: 8.4519
# Epoch 449/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.6044 - mean_absolute_error: 1.6044 - val_loss: 8.3203 - val_mean_absolute_error: 8.3203
# Epoch 450/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5860 - mean_absolute_error: 1.5860 - val_loss: 8.4100 - val_mean_absolute_error: 8.4100
# Epoch 451/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5700 - mean_absolute_error: 1.5700 - val_loss: 8.3731 - val_mean_absolute_error: 8.3731
# Epoch 452/600
# 187/187 [==============================] - 1s 3ms/step - loss: 1.5862 - mean_absolute_error: 1.5862 - val_loss: 8.4283 - val_mean_absolute_error: 8.4283
# Epoch 453/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5562 - mean_absolute_error: 1.5562 - val_loss: 8.2763 - val_mean_absolute_error: 8.2763
# Epoch 454/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5526 - mean_absolute_error: 1.5526 - val_loss: 8.3746 - val_mean_absolute_error: 8.3746
# Epoch 455/600
# 187/187 [==============================] - 1s 3ms/step - loss: 1.5559 - mean_absolute_error: 1.5559 - val_loss: 8.1828 - val_mean_absolute_error: 8.1828
# Epoch 456/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5701 - mean_absolute_error: 1.5701 - val_loss: 8.4434 - val_mean_absolute_error: 8.4434
# Epoch 457/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5451 - mean_absolute_error: 1.5451 - val_loss: 8.4617 - val_mean_absolute_error: 8.4617
# Epoch 458/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5452 - mean_absolute_error: 1.5452 - val_loss: 8.3466 - val_mean_absolute_error: 8.3466
# Epoch 459/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5089 - mean_absolute_error: 1.5089 - val_loss: 8.4015 - val_mean_absolute_error: 8.4015
# Epoch 460/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5396 - mean_absolute_error: 1.5396 - val_loss: 8.4840 - val_mean_absolute_error: 8.4840
# Epoch 461/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5344 - mean_absolute_error: 1.5344 - val_loss: 8.4441 - val_mean_absolute_error: 8.4441
# Epoch 462/600
# 187/187 [==============================] - 1s 3ms/step - loss: 1.5491 - mean_absolute_error: 1.5491 - val_loss: 8.4214 - val_mean_absolute_error: 8.4214
# Epoch 463/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5321 - mean_absolute_error: 1.5321 - val_loss: 8.4698 - val_mean_absolute_error: 8.4698
# Epoch 464/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5413 - mean_absolute_error: 1.5413 - val_loss: 8.4234 - val_mean_absolute_error: 8.4234
# Epoch 465/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5543 - mean_absolute_error: 1.5543 - val_loss: 8.4565 - val_mean_absolute_error: 8.4565
# Epoch 466/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5743 - mean_absolute_error: 1.5743 - val_loss: 8.5057 - val_mean_absolute_error: 8.5057
# Epoch 467/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5377 - mean_absolute_error: 1.5377 - val_loss: 8.4653 - val_mean_absolute_error: 8.4653
# Epoch 468/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5649 - mean_absolute_error: 1.5649 - val_loss: 8.5177 - val_mean_absolute_error: 8.5177
# Epoch 469/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5375 - mean_absolute_error: 1.5375 - val_loss: 8.3365 - val_mean_absolute_error: 8.3365
# Epoch 470/600
# 187/187 [==============================] - 1s 6ms/step - loss: 1.5150 - mean_absolute_error: 1.5150 - val_loss: 8.4764 - val_mean_absolute_error: 8.4764
# Epoch 471/600
# 187/187 [==============================] - 1s 5ms/step - loss: 1.5394 - mean_absolute_error: 1.5394 - val_loss: 8.4529 - val_mean_absolute_error: 8.4529
# Epoch 472/600
# 187/187 [==============================] - 1s 6ms/step - loss: 1.5625 - mean_absolute_error: 1.5625 - val_loss: 8.4293 - val_mean_absolute_error: 8.4293
# Epoch 473/600
# 187/187 [==============================] - 1s 5ms/step - loss: 1.5137 - mean_absolute_error: 1.5137 - val_loss: 8.5331 - val_mean_absolute_error: 8.5331
# Epoch 474/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5362 - mean_absolute_error: 1.5362 - val_loss: 8.3716 - val_mean_absolute_error: 8.3716
# Epoch 475/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5506 - mean_absolute_error: 1.5506 - val_loss: 8.3016 - val_mean_absolute_error: 8.3016
# Epoch 476/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5041 - mean_absolute_error: 1.5041 - val_loss: 8.4633 - val_mean_absolute_error: 8.4633
# Epoch 477/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5212 - mean_absolute_error: 1.5212 - val_loss: 8.3271 - val_mean_absolute_error: 8.3271
# Epoch 478/600
# 187/187 [==============================] - 1s 7ms/step - loss: 1.5292 - mean_absolute_error: 1.5292 - val_loss: 8.3609 - val_mean_absolute_error: 8.3609
# Epoch 479/600
# 187/187 [==============================] - 2s 8ms/step - loss: 1.5454 - mean_absolute_error: 1.5454 - val_loss: 8.4570 - val_mean_absolute_error: 8.4570
# Epoch 480/600
# 187/187 [==============================] - 1s 7ms/step - loss: 1.5135 - mean_absolute_error: 1.5135 - val_loss: 8.4247 - val_mean_absolute_error: 8.4247
# Epoch 481/600
# 187/187 [==============================] - 1s 8ms/step - loss: 1.5251 - mean_absolute_error: 1.5251 - val_loss: 8.4188 - val_mean_absolute_error: 8.4188
# Epoch 482/600
# 187/187 [==============================] - 1s 7ms/step - loss: 1.5194 - mean_absolute_error: 1.5194 - val_loss: 8.3711 - val_mean_absolute_error: 8.3711
# Epoch 483/600
# 187/187 [==============================] - 1s 5ms/step - loss: 1.5203 - mean_absolute_error: 1.5203 - val_loss: 8.3641 - val_mean_absolute_error: 8.3641
# Epoch 484/600
# 187/187 [==============================] - 1s 6ms/step - loss: 1.5312 - mean_absolute_error: 1.5312 - val_loss: 8.2984 - val_mean_absolute_error: 8.2984
# Epoch 485/600
# 187/187 [==============================] - 1s 5ms/step - loss: 1.5061 - mean_absolute_error: 1.5061 - val_loss: 8.3062 - val_mean_absolute_error: 8.3062
# Epoch 486/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5069 - mean_absolute_error: 1.5069 - val_loss: 8.3958 - val_mean_absolute_error: 8.3958
# Epoch 487/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5336 - mean_absolute_error: 1.5336 - val_loss: 8.2165 - val_mean_absolute_error: 8.2165
# Epoch 488/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5199 - mean_absolute_error: 1.5199 - val_loss: 8.3990 - val_mean_absolute_error: 8.3990
# Epoch 489/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5739 - mean_absolute_error: 1.5739 - val_loss: 8.3288 - val_mean_absolute_error: 8.3288
# Epoch 490/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5046 - mean_absolute_error: 1.5046 - val_loss: 8.3574 - val_mean_absolute_error: 8.3574
# Epoch 491/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5373 - mean_absolute_error: 1.5373 - val_loss: 8.3528 - val_mean_absolute_error: 8.3528
# Epoch 492/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.4861 - mean_absolute_error: 1.4861 - val_loss: 8.3379 - val_mean_absolute_error: 8.3379
# Epoch 493/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.4954 - mean_absolute_error: 1.4954 - val_loss: 8.3621 - val_mean_absolute_error: 8.3621
# Epoch 494/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5204 - mean_absolute_error: 1.5204 - val_loss: 8.3782 - val_mean_absolute_error: 8.3782
# Epoch 495/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5095 - mean_absolute_error: 1.5095 - val_loss: 8.5018 - val_mean_absolute_error: 8.5018
# Epoch 496/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5010 - mean_absolute_error: 1.5010 - val_loss: 8.4381 - val_mean_absolute_error: 8.4381
# Epoch 497/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5079 - mean_absolute_error: 1.5079 - val_loss: 8.3849 - val_mean_absolute_error: 8.3849
# Epoch 498/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5649 - mean_absolute_error: 1.5649 - val_loss: 8.2505 - val_mean_absolute_error: 8.2505
# Epoch 499/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5012 - mean_absolute_error: 1.5012 - val_loss: 8.2575 - val_mean_absolute_error: 8.2575
# Epoch 500/600
# 187/187 [==============================] - 1s 5ms/step - loss: 1.5422 - mean_absolute_error: 1.5422 - val_loss: 8.3922 - val_mean_absolute_error: 8.3922
# Epoch 501/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5242 - mean_absolute_error: 1.5242 - val_loss: 8.4897 - val_mean_absolute_error: 8.4897
# Epoch 502/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5299 - mean_absolute_error: 1.5299 - val_loss: 8.3028 - val_mean_absolute_error: 8.3028
# Epoch 503/600
# 187/187 [==============================] - 1s 5ms/step - loss: 1.5207 - mean_absolute_error: 1.5207 - val_loss: 8.3540 - val_mean_absolute_error: 8.3540
# Epoch 504/600
# 187/187 [==============================] - 1s 3ms/step - loss: 1.5125 - mean_absolute_error: 1.5125 - val_loss: 8.5699 - val_mean_absolute_error: 8.5699
# Epoch 505/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5104 - mean_absolute_error: 1.5104 - val_loss: 8.4292 - val_mean_absolute_error: 8.4292
# Epoch 506/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.4827 - mean_absolute_error: 1.4827 - val_loss: 8.4247 - val_mean_absolute_error: 8.4247
# Epoch 507/600
# 187/187 [==============================] - 1s 5ms/step - loss: 1.5132 - mean_absolute_error: 1.5132 - val_loss: 8.4076 - val_mean_absolute_error: 8.4076
# Epoch 508/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.4915 - mean_absolute_error: 1.4915 - val_loss: 8.4579 - val_mean_absolute_error: 8.4579
# Epoch 509/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.4786 - mean_absolute_error: 1.4786 - val_loss: 8.2982 - val_mean_absolute_error: 8.2982
# Epoch 510/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.5035 - mean_absolute_error: 1.5035 - val_loss: 8.4732 - val_mean_absolute_error: 8.4732
# Epoch 511/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.4859 - mean_absolute_error: 1.4859 - val_loss: 8.5133 - val_mean_absolute_error: 8.5133
# Epoch 512/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.4979 - mean_absolute_error: 1.4979 - val_loss: 8.4783 - val_mean_absolute_error: 8.4783
# Epoch 513/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.4857 - mean_absolute_error: 1.4857 - val_loss: 8.5028 - val_mean_absolute_error: 8.5028
# Epoch 514/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.4988 - mean_absolute_error: 1.4988 - val_loss: 8.4394 - val_mean_absolute_error: 8.4394
# Epoch 515/600
# 187/187 [==============================] - 1s 4ms/step - loss: 1.4762 - mean_absolute_error: 1.4762 - val_loss: 8.3361 - val_mean_absolute_error: 8.3361
# Epoch 516/600
# 187/187 [==============================] - 1s 5ms/step - loss: 1.5019 - mean_absolute_error: 1.5019 - val_loss: 8.2960 - val_mean_absolute_error: 8.2960
# Epoch 517/600
# 187/187 [==============================] - 1s 5ms/step - loss: 1.4938 - mean_absolute_error: 1.4938 - val_loss: 8.4233 - val_mean_absolute_error: 8.4233
# Epoch 518/600
#  22/187 [==>...........................] - ETA: 0s - loss: 1.4668 - mean_absolute_error: 1.4668
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-203b14dc18fe> in <module>
#      10 model.compile(optimizer='adam',loss='mean_absolute_error',metrics=['mean_absolute_error'])
#      11
# ---> 12 history = model.fit(X_train,y_train,validation_split=0.2,batch_size=32,epochs=600)
#      13     #callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
# Make predictions and calculate the scores
y_pred = (model.predict(X_test))

print(mean_squared_error(y_test, y_pred))
print(math.sqrt(mean_squared_error(y_test, y_pred)))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 301.80681139623914
# 17.372587930306732
# 6.918023560203639
# 0.5683944345747445

# %% [markdown]
# ## XGBRegressor

# %%
from xgboost import XGBRegressor
reg = XGBRegressor(n_estimators=1000, max_depth=5, eta=0.1, subsample=0.7, colsample_bytree=0.8)
f = reg.fit(X_train, y_train)

# %%
y_pred = (f.predict(X_test))

print(mean_squared_error(y_test, y_pred))
print(math.sqrt(mean_squared_error(y_test, y_pred)))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 249.51548232633579
# 15.796059075805452
# 7.963607251204364
# 0.6431748165868085

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7, 0.8]}
reg = GridSearchCV(estimator=XGBRegressor(),
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=1)
reg.fit(X, y)
print("Best parameters:", reg.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best parameters: {'colsample_bytree': 0.3, 'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 1000}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-95b7ebce2f02> in <module>
#       9 reg.fit(X, y)
#      10 print("Best parameters:", reg.best_params_)
# ---> 11 print("Lowest RMSE: ", (-clf.best_score_)**(1/2))
#
# NameError: name 'clf' is not defined

# %%
print("Lowest RMSE: ", (-reg.best_score_)**(1/2))
# Out:
# Lowest RMSE:  22.757760684383033

# %%
best_model = reg.best_estimator_

# %%
y_pred = (best_model.predict(X_test))

print(mean_squared_error(y_test, y_pred))
print(math.sqrt(mean_squared_error(y_test, y_pred)))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 6.577379538782479
# 2.564640235741161
# 1.3438684912665078
# 0.9905938716170138

# %%
# Save the best model
pickle.dump(best_model, open('best_delay_model.pkl', 'wb'))
